# %%
import pandas as pd
import matplotlib.pyplot as plt


dados =pd.read_csv("/content/linear_graph_data.csv")



plt.plot(dados['Timestamp'], dados['Value'])
plt.title("Exemplo de Gráfico")
plt.xlabel("vibração")
plt.ylabel("temperatura")

plt.xlim(0,5)

plt.show()

dados.columns
# Out:
# Index(['Timestamp', 'Value'], dtype='object')

# %%
dados.columns

dados['Value'].max()
# Out:
# 63.67
